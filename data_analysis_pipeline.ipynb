# %%
from stock_analysis import StockAnalysis


# datasets
dataset_prevoid = 'Datasets/Data_PreCovid_20170101_20200109.csv'
metadata_file = 'Datasets/Stock_metadata.csv'
analysis = StockAnalysis(returns_file_path=dataset_prevoid, metadata_file_path=metadata_file)
# analysis.complete_analysis()

# %%
#  self.calculate_covariance_matrix()
        # self.linear_shrinkage()
        # self.generate_scree_plot()
        # self.eigenvalue_histogram()
        # self.compare_with_gaussian()
        # self.analyze_top_eigenvectors()
        # self.covariance_matrix_reconstruction()
        # self.spectral_clustering()
        # self.compare_covariance_estimators()

analysis.returns_data
# Out:
#          0         1         2         3         4         5         6    \
# 0   0.003018  0.001466  0.005935  0.009630  0.008779  0.002859  0.008470
# 1  -0.008139  0.010323  0.006134 -0.001410  0.006406  0.000312 -0.035982
# 2  -0.007869 -0.001455 -0.017158  0.011328 -0.009864  0.001043  0.006220
# 3   0.000483  0.003848  0.016950  0.021655  0.005634 -0.002859  0.006997
# 4  -0.003976 -0.000954  0.002535  0.003808 -0.010378 -0.007378  0.015472
# ..       ...       ...       ...       ...       ...       ...       ...
# 93  0.009352  0.008898  0.009292  0.011131 -0.006462 -0.004785  0.006746
# 94  0.011425 -0.000550 -0.002559 -0.007669 -0.010198  0.001328 -0.003045
# 95 -0.014106  0.008585  0.012696  0.005420 -0.002920 -0.023545  0.001356
# 96 -0.008412  0.005809  0.011334 -0.002195  0.005546 -0.005991  0.004827
# 97 -0.000550 -0.013591 -0.018351 -0.003271 -0.013466 -0.014327  0.010538
#
#          7         8         9    ...       749       750       751       752  \
# 0   0.002939 -0.000588  0.013930  ... -0.001476  0.017713 -0.004545  0.007091
# 1   0.008357  0.010378  0.001780  ... -0.006103 -0.004110 -0.008706 -0.007877
# 2   0.001383  0.013775  0.000948  ...  0.004262  0.002077 -0.001083 -0.007567
# 3   0.005541 -0.002852  0.001946  ...  0.001943  0.004752 -0.006298 -0.006103
# 4   0.005228  0.002058  0.005658  ...  0.000213  0.000320  0.002658  0.000745
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 93  0.003940  0.001850  0.006172  ...  0.002509  0.006737 -0.001846 -0.007849
# 94  0.004757 -0.003230  0.003609  ... -0.002933  0.000163  0.002278 -0.007163
# 95  0.011434 -0.001050  0.003274  ...  0.001252  0.005732  0.003093  0.005694
# 96 -0.005721 -0.012582  0.004688  ...  0.003185 -0.000753 -0.002922 -0.003345
# 97 -0.010714  0.000927  0.008969  ... -0.004702 -0.000855 -0.004426 -0.008741
#
#          753       754       755       756       757       758
# 0   0.012749  0.013779  0.000942  0.020250 -0.004848  0.020089
# 1   0.003734  0.005262  0.005993  0.013287 -0.000450  0.004142
# 2   0.002806 -0.003373  0.006216  0.000768  0.003586  0.001616
# 3   0.010853  0.013335  0.007988  0.016375 -0.002277  0.012089
# 4   0.003604 -0.011066  0.000857  0.003422  0.004386  0.000000
# ..       ...       ...       ...       ...       ...       ...
# 93  0.004480  0.011154  0.006296  0.006310 -0.004758  0.012742
# 94  0.003099 -0.005391 -0.003141  0.002658 -0.008354  0.000670
# 95  0.008843 -0.024041  0.023700  0.008491 -0.002914  0.004263
# 96 -0.005538  0.000673 -0.003218  0.002127 -0.005988 -0.001204
# 97  0.010951  0.009353 -0.014259  0.007791 -0.002983 -0.012631
#
# [98 rows x 759 columns]

# %%
covmatrix = analysis.returns_data.cov()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
